# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 500)

# %%
data = pd.read_csv('./data/192072450_RESI_65E2/listing.txt', sep="\t")

# %%
data.to_json('./data/192072450_RESI_65E2.json')

# %%
# data
# Out:
#     ML Number          Status  List Price  Sold Price List Date  Sold Date  \
# 0      127312         Expired      1384.0         0.0  04/26/17        NaN
# 1      127313         Expired       810.0         0.0  04/26/17        NaN
# 2      127326         Expired       665.0         0.0  04/26/17        NaN
# 3      127846         Expired   1749000.0         0.0  07/05/17        NaN
# 4      129698  Active Pending   1690000.0         0.0  07/30/18        NaN
# 5      129896       Withdrawn   2300000.0         0.0  09/08/18        NaN
# 6      130298          Active   1449000.0         0.0  01/05/19        NaN
# 7      130385          Active    400000.0         0.0  02/01/19        NaN
# 8      130433         Expired      5385.0         0.0  02/20/19        NaN
# 9      130449       Cancelled   1499000.0         0.0  02/25/19        NaN
# 10     130483          Active   1990000.0         0.0  03/12/19        NaN
# ...
